# %% [markdown]
# # 📉STOCK MARKET ANALYSIS

# %%
#Importing required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Fetching the dataset

# %%
full_df=pd.DataFrame()
path=r'C:\Users\saish\Downloads\Work\Stocks\individual_stocks_5yr-20230326T090755Z-001\individual_stocks_5yr'
files_csv=['AAPL_data.csv','GOOG_data.csv','MSFT_data.csv','AMZN_data.csv']
for file in files_csv:
    current_df=pd.read_csv(path+'/'+file,on_bad_lines='skip')
    full_df=pd.concat([full_df,current_df])

# %%
#Analyzing the fetched dataset

# %%
full_df.shape

# %%
full_df.head(10)
# Out:
#         date     open     high      low    close     volume  Name  \
# 0 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 5 2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL
# 6 2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL
# 7 2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL
# 8 2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL
# 9 2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL
#
#    price_change    return
# 0        0.1400  0.206325
# 1        0.4900  0.714688
# 2       -1.6586 -2.481344
# 3       -0.0286 -0.042869
# 4        0.2957  0.443624
# 5       -1.2414 -1.888431
# 6       -0.1586 -0.241353
# ...

# %%
#Making a list of all the comapnies.

# %%
tech_list=full_df['Name'].unique()
tech_list
# Out:
# array(['AAPL', 'GOOG', 'MSFT', 'AMZN'], dtype=object)

# %%
#Converting the date feature's data type inot datetime

# %%
full_df['date']=pd.to_datetime(full_df['date'])

# %% [markdown]
# ## Ploting The Closing Price Of The Company's Stock.

# %%
plt.figure(figsize=(20,12))
for i,company in enumerate(tech_list,1):
    plt.subplot(2,2,i)
    df=full_df[full_df['Name']==company]
    color=['yellow','red','blue','green','purple']
    list_c=['list','Apple','Google','Microsoft','Amazon']
    plt.plot(df['date'],df['close'],color=color[i])
    plt.xticks(rotation='vertical')
    plt.title(list_c[i],color=color[i],fontsize=16)
    plt.tight_layout()

# %%
## Conclusion - All the above stocks have an upward trend over the years

# %% [markdown]
# ## Comparing The Total Volume Of Stocks Traded Based On Dates.

# %%
import plotly.express as px

# %%
for i in tech_list:
    dfs=full_df[full_df['Name']==i]
    fig=px.line(dfs,x='date',y='volume',title=i,color_discrete_sequence=['purple'])
    fig.show()
# Out:
# <div>                            <div id="c9495bc8-803e-45e7-808c-4977bfe7fc21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9495bc8-803e-45e7-808c-4977bfe7fc21")) {                    Plotly.newPlot(                        "c9495bc8-803e-45e7-808c-4977bfe7fc21",                        [{"hovertemplate":"date=%{x}<br>volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"purple","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02
# ...

# %%
#Using Image since GitHub doesnt support iplot
from IPython.display import Image
Image(filename='AAPL.png')

# %%
#Using Image since GitHub doesnt support iplot
from IPython.display import Image
Image(filename='GOOG.png')

# %%
#Using Image since GitHub doesnt support iplot
from IPython.display import Image
Image(filename='MSFT.png')

# %%
#Using Image since GitHub doesnt support iplot
from IPython.display import Image
Image(filename='AMZN.png')

# %%
### Conclusion: Microsoft resulted in maximum volume trade on July 19, 2013

# %%
### Creating A New Feature Called 'Price Change' Which Is Closed Price - Open Price

# %%
full_df['price_change']=full_df['close']-full_df['open']

# %%
full_df.head()
# Out:
#         date     open     high      low    close     volume  Name  \
# 0 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    price_change
# 0        0.1400
# 1        0.4900
# 2       -1.6586
# 3       -0.0286
# 4        0.2957

# %%
### Calculation the returns percentage

# %%
full_df['return']=(full_df['price_change']/full_df['close'])*100

# %%
full_df.head()
# Out:
#         date     open     high      low    close     volume  Name  \
# 0 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    price_change    return
# 0        0.1400  0.002063
# 1        0.4900  0.007147
# 2       -1.6586 -0.024813
# 3       -0.0286 -0.000429
# 4        0.2957  0.004436

# %%
df=full_df[full_df['Name']=='AAPL']

# %%
df['Name'].unique()
# Out:
# array(['AAPL'], dtype=object)

# %% [markdown]
# ## Plotting The Returns% Graph For Apple

# %%
fig=px.line(df,x='date',y='return',title='Apple Returns%',color_discrete_sequence=['red'])
fig.show()
# Out:
# <div>                            <div id="6b40cc37-b2f6-4ec2-a564-89992c315d31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b40cc37-b2f6-4ec2-a564-89992c315d31")) {                    Plotly.newPlot(                        "6b40cc37-b2f6-4ec2-a564-89992c315d31",                        [{"hovertemplate":"date=%{x}<br>return=%{y}<extra></extra>","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27
# ...

# %%
#Using Image since GitHub doesnt support iplot
from IPython.display import Image
Image(filename='AppleReturns.png')

# %% [markdown]
# ## Plotting The Graph For Close Price Mean Per Month

# %%
new_df.head()
# Out:
#                open     high      low    close     volume  Name
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
### To gather this data we need to set the index to date feature and then use resample('M').mean() to return close price's mean per month

# %%
new_df.set_index('date',inplace=True)

# %%
new_df['close'].resample('M').mean().plot(lw=5)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
pd.DataFrame(df3)

# %%
import pandas as pd
d_df=pd.DataFrame()
path=r'C:\Users\saish\Downloads\Work\Stocks\individual_stocks_5yr-20230326T090755Z-001\individual_stocks_5yr'
files_csv=['AAPL_data.csv','GOOG_data.csv','MSFT_data.csv','AMZN_data.csv']
for file in files_csv:
    current_df=pd.read_csv(path+'/'+file,on_bad_lines='skip')
    d_df=pd.concat([d_df,current_df]) 
    d_df=d_df[['close','Name']]

# %%
d_df.head()
# Out:
#      close  Name
# 0  67.8542  AAPL
# 1  68.5614  AAPL
# 2  66.8428  AAPL
# 3  66.7156  AAPL
# 4  66.6556  AAPL

# %% [markdown]
# ## Find Correlation Between Closing Price of Each Stocks

# %%
pivoted_df = d_df.pivot(columns='Name', values='close')
pivoted_df=pd.DataFrame(pivoted_df)

# %%
pivoted_df.columns
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'MSFT'], dtype='object', name='Name')

# %%
pivoted_df.corr()
# Out:
# Name      AAPL      AMZN      GOOG      MSFT
# Name
# AAPL  1.000000  0.819078  0.640522  0.899689
# AMZN  0.819078  1.000000  0.888456  0.955977
# GOOG  0.640522  0.888456  1.000000  0.907011
# MSFT  0.899689  0.955977  0.907011  1.000000

# %%
sns.heatmap(pivoted_df.corr(),annot=True,cmap='YlOrRd')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Name'>

# %%
## Conclusion : There is a strong correlation between MSFT and AMZN stocks. Similarly we can see a strong correlation between GOOG and MSFT also AAPL and MSFT

# %%
import seaborn as sns
sns.pairplot(pivoted_df)

# %%
## Conclusion : Here we can see for (MSFT,GOOG) , (MSFT,AAPL) and (MSFT,AMZN) we have a linear projection.

# %% [markdown]
# ## Find The Correlation Between The Return% Of Each Stock

# %%
new_pivot=full_df.pivot(columns='Name',values='return')

# %%
new_pivot
# Out:
# Name      AAPL      AMZN      GOOG      MSFT
# 0     0.206325  0.209964 -1.708269  0.725953
# 1     0.714688 -2.328836 -0.216075  0.753769
# 2    -2.481344 -0.189409 -1.781065  0.000000
# 3    -0.042869  2.946525  1.489879  0.356761
# 4     0.443624  0.694548  0.334039  0.427960
# ...        ...       ...       ...       ...
# 1254  0.366551 -3.956835       NaN -0.562275
# 1255 -3.426791 -3.317599       NaN -2.026585
# 1256 -1.667838 -0.907914       NaN -2.909091
# 1257  5.029749  5.640265       NaN  4.861491
# 1258 -2.222013 -2.274171       NaN -0.982033
#
# [1259 rows x 4 columns]

# %%
sns.pairplot(new_pivot)

# %%
sns.heatmap(new_pivot.corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Name'>

# %%
### Conclusion: While Plotting both Pairplot and Heatmap we can see the there litte too less correlation between the returns.
### Microsoft and Apple has the highest correlation 0f 0.42

# %% [markdown]
# ## Find Which Stock Has More Risk In Buying

# %%
new_pivot.head()
# Out:
# Name      AAPL      AMZN      GOOG      MSFT
# 0     0.206325  0.209964 -1.708269  0.725953
# 1     0.714688 -2.328836 -0.216075  0.753769
# 2    -2.481344 -0.189409 -1.781065  0.000000
# 3    -0.042869  2.946525  1.489879  0.356761
# 4     0.443624  0.694548  0.334039  0.427960

# %%
### We plot Distplot to show how the return% is distributed

# %%
sns.distplot(new_pivot['AAPL'],kde=True)
# Out:
# <AxesSubplot:xlabel='AAPL', ylabel='Density'>

# %%
print("Standard Deviation of 1 = {},\nStandard Deviation of 2 = {},\nStandard Deviation of 3 = {}".format(new_pivot['AAPL'].std(),new_pivot['AAPL'].std()*2,new_pivot['AAPL'].std()*3))
# Out:
# Standard Deviation of 1 = 1.1871377131421237,
# Standard Deviation of 2 = 2.3742754262842474,
# Standard Deviation of 3 = 3.561413139426371

# %%
sns.distplot(new_pivot['GOOG'],kde=True)
# Out:
# <AxesSubplot:xlabel='GOOG', ylabel='Density'>

# %%
print("Standard Deviation of 1 = {},\nStandard Deviation of 2 = {},\nStandard Deviation of 3 = {}".format(new_pivot['GOOG'].std(),new_pivot['GOOG'].std()*2,new_pivot['GOOG'].std()*3))
# Out:
# Standard Deviation of 1 = 1.0925596178210477,
# Standard Deviation of 2 = 2.1851192356420954,
# Standard Deviation of 3 = 3.277678853463143

# %%
sns.distplot(new_pivot['MSFT'],kde=True)
# Out:
# <AxesSubplot:xlabel='MSFT', ylabel='Density'>

# %%
print("Standard Deviation of 1 = {},\nStandard Deviation of 2 = {},\nStandard Deviation of 3 = {}".format(new_pivot['MSFT'].std(),new_pivot['MSFT'].std()*2,new_pivot['MSFT'].std()*3))
# Out:
# Standard Deviation of 1 = 1.059259601884536,
# Standard Deviation of 2 = 2.118519203769072,
# Standard Deviation of 3 = 3.177778805653608

# %%
sns.distplot(new_pivot['AMZN'],kde=True)
# Out:
# <AxesSubplot:xlabel='AMZN', ylabel='Density'>

# %%
print("Standard Deviation of 1 = {},\nStandard Deviation of 2 = {},\nStandard Deviation of 3 = {}".format(new_pivot['AMZN'].std(),new_pivot['AMZN'].std()*2,new_pivot['AMZN'].std()*3))
# Out:
# Standard Deviation of 1 = 1.35867860994955,
# Standard Deviation of 2 = 2.7173572198991,
# Standard Deviation of 3 = 4.07603582984865

# %%
## Conclusion : The std of 1 means 68% of the data lies in this region. STD of 2 means 95% of data lies in this region
## and std of 3 means 99% of data lies in this region.

# %%
# Apple - 99% lies between (-3.561413139426371 to 3.561413139426371). So most of the time the returns will be within this range.
# Google - 99% lies between (-3.277678853463143 to 3.277678853463143).
# Microsoft - 99% lies between (-3.177778805653608 to 3.177778805653608).
# Amazon - 99% lies between (-4.07603582984865 to 4.07603582984865).
